# %%
from ultralytics import YOLO
import torch


# Configure device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using: {device.upper()}")

# Load model once
model = YOLO(r"D:\DEPI PROJECT PAVEMENT EYE\PavementEye\models\fine_tunning\runs\main_trainging\yolov8s\weights\best.pt")
model.to(device)
# Out:
# Using: CPU
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# results = model.predict(
#     source=r"D:\1.JPG",
#     conf=0.25,
#     imgsz=1280,
#     device=device,
#     half=True if device == 'cuda' else False,
#     vid_stride=2,
#     save=True,
#     tracker="bytetrack.yaml",
#     stream=True,
#     verbose=True
# )
# count = 0
# for r in results:
#     count += 1
#     if count % 100 == 0:
#         print(f"Processed {count} frames...")
#
# print(f"\n✓ Done! Processed {count} frames")
# print("Output: runs/detect/predict")

# %%
results = model.predict(
    source=r"C:\Users\moham\Videos\IMG_1336.MOV",
    conf=0.25,
    imgsz=1280,
    device=device,
    half=True if device == 'cuda' else False,
    vid_stride=2,
    save=True,
    tracker="bytetrack.yaml",
    stream=True,
    verbose=True
)

# Process
count = 0
for r in results:
    count += 1
    if count % 100 == 0:
        print(f"Processed {count} frames...")

print(f"\n✓ Done! Processed {count} frames")
print("Output: runs/detect/predict")
# Out:
# video 1/1 (frame 1/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 1 Bleeding, 795.5ms
# video 1/1 (frame 2/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 939.8ms
# video 1/1 (frame 3/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 1021.9ms
# video 1/1 (frame 4/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 1 Potholes, 563.5ms
# video 1/1 (frame 5/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 558.2ms
# video 1/1 (frame 6/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 542.5ms
# video 1/1 (frame 7/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 553.2ms
# video 1/1 (frame 8/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 563.3ms
# video 1/1 (frame 9/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 (no detections), 602.8ms
# video 1/1 (frame 10/2114) C:\Users\moham\Videos\IMG_1336.MOV: 736x1280 1 Potholes, 511.1ms
# ...
